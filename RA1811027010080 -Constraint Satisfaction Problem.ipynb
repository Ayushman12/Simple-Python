# %% [markdown]
# # $\;\;\;\;\;\;$ $\;\;\;\;\;\;\;\;\;\;\;\;$Constraint Satisfaction Problem

# %% [markdown]
# ### Aim:
#
# Implementation of Constraint Satisfaction Problem (CSP) using python programming

# %% [markdown]
# ## Manual Procedure

# %% [markdown]
# ![upePrac.jpeg](attachment:upePrac.jpeg)

# %%
import itertools

def get_value(word, substitution):
    # Converts words in numbers
    s = 0
    factor = 1
    for letter in reversed(word):
        s += factor * substitution[letter]
        factor *= 10
    return s


def solve(equation):
    
    # split equation in left and right
    left, right = equation.lower().replace(' ', '').split('=')
    
    # split words in left part
    left = left.split('+')
    
    # create list of used letters
    letters = set(right)
    for word in left:
        for letter in word:
            letters.add(letter)
    letters = list(letters)
    
    #creating diff permutations
    digits = range(10)
    for perm in itertools.permutations(digits, len(letters)):
        sol = dict(zip(letters, perm))
        
        # check if sum is equal and print
        if sum(get_value(word, sol) for word in left) == get_value(right, sol):
            print(' + '.join(str(get_value(word, sol)) for word in left) + " = {} \n(mapping: {})\n".format(get_value(right, sol), sol))

if __name__ == '__main__':
    s = input("Enter Cryptarithmetic Problem : ")
    print()
    solve(s)
# Out:
# Enter Cryptarithmetic Problem : SEND+MORE=MONEY
#
# 9567 + 1085 = 10652
# (mapping: {'o': 0, 'm': 1, 's': 9, 'r': 8, 'd': 7, 'n': 6, 'y': 2, 'e': 5})
#
# 2817 + 368 = 3185
# (mapping: {'o': 3, 'm': 0, 's': 2, 'r': 6, 'd': 7, 'n': 1, 'y': 5, 'e': 8})
#
# 2819 + 368 = 3187
# (mapping: {'o': 3, 'm': 0, 's': 2, 'r': 6, 'd': 9, 'n': 1, 'y': 7, 'e': 8})
#
# 3719 + 457 = 4176
# (mapping: {'o': 4, 'm': 0, 's': 3, 'r': 5, 'd': 9, 'n': 1, 'y': 6, 'e': 7})
#
# 3829 + 458 = 4287
# (mapping: {'o': 4, 'm': 0, 's': 3, 'r': 5, 'd': 9, 'n': 2, 'y': 7, 'e': 8})
#
# 3821 + 468 = 4289
# (mapping: {'o': 4, 'm': 0, 's': 3, 'r': 6, 'd': 1, 'n': 2, 'y': 9, 'e': 8})
#
# 3712 + 467 = 4179
# (mapping: {'o': 4, 'm': 0, 's': 3, 'r': 6, 'd': 2, 'n': 1, 'y': 9, 'e': 7})
#
# 5849 + 638 = 6487
# (mapping: {'o': 6, 'm': 0, 's': 5, 'r': 3, 'd': 9, 'n': 4, 'y': 7, 'e': 8})
#
# 5731 + 647 = 6378
# (mapping: {'o': 6, 'm': 0, 's': 5, 'r': 4, 'd': 1, 'n': 3, 'y': 8, 'e': 7})
#
# 5732 + 647 = 6379
# ...

# %% [markdown]
# ### Result:
# Constraint Satisfaction Problem was implemented successfully using Python programming.
